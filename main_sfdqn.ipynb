# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# %%
from main_sfdqn import *

# %%
agent, tasks = main()

# %%
rewards = agent.test_agent(tasks[0], return_history=1, visualize=1)
