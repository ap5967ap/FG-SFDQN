# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
from main_sfdqn import *

# %%
agent, tasks = main()
# Out:
# test performance:
# /home/ritish/prog/ML/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ritish/prog/ML/.venv/lib/python3.13/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# task 	 0 	 steps 	 1000 	 episodes 	 5 	 eps 	 0.5500	ep_reward 	 10.0000 	 reward 	 10.0000	GPI% 	 0.0000 	 w_err 	 9.9973
# test performance:
# task 	 0 	 steps 	 2000 	 episodes 	 10 	 eps 	 0.5500	ep_reward 	 0.0000 	 reward 	 40.0000	GPI% 	 0.0000 	 w_err 	 9.8496
# test performance:
# task 	 0 	 steps 	 3000 	 episodes 	 15 	 eps 	 0.5500	ep_reward 	 0.0000 	 reward 	 70.0000	GPI% 	 0.0000 	 w_err 	 9.7041
# test performance:
# task 	 0 	 steps 	 4000 	 episodes 	 21 	 eps 	 0.5500	ep_reward 	 0.0000 	 reward 	 112.0000	GPI% 	 0.0000 	 w_err 	 9.5125
# test performance:
# task 	 0 	 steps 	 5000 	 episodes 	 27 	 eps 	 0.5500	ep_reward 	 1.0000 	 reward 	 164.0000	GPI% 	 0.0000 	 w_err 	 9.2786
# test performance:
# task 	 0 	 steps 	 6000 	 episodes 	 34 	 eps 	 0.5500	ep_reward 	 11.0000 	 reward 	 258.0000	GPI% 	 0.0000 	 w_err 	 8.8719
# test performance:
# task 	 0 	 steps 	 7000 	 episodes 	 39 	 eps 	 0.5500	ep_reward 	 0.0000 	 reward 	 290.0000	GPI% 	 0.0000 	 w_err 	 8.7400
# test performance:
# task 	 0 	 steps 	 8000 	 episodes 	 45 	 eps 	 0.5500	ep_reward 	 0.0000 	 reward 	 332.0000	GPI% 	 0.0000 	 w_err 	 8.5675
# test performance:
# task 	 0 	 steps 	 9000 	 episodes 	 50 	 eps 	 0.5500	ep_reward 	 10.0000 	 reward 	 412.0000	GPI% 	 0.0000 	 w_err 	 8.2349
# test performance:
# task 	 0 	 steps 	 10000 	 episodes 	 55 	 eps 	 0.5500	ep_reward 	 20.0000 	 reward 	 463.0000	GPI% 	 0.0000 	 w_err 	 8.0333
# test performance:
# task 	 0 	 steps 	 11000 	 episodes 	 61 	 eps 	 0.5500	ep_reward 	 20.0000 	 reward 	 514.0000	GPI% 	 0.0000 	 w_err 	 7.8367
# test performance:
# task 	 0 	 steps 	 12000 	 episodes 	 66 	 eps 	 0.5500	ep_reward 	 10.0000 	 reward 	 584.0000	GPI% 	 0.0000 	 w_err 	 7.5704
# test performance:
# task 	 0 	 steps 	 13000 	 episodes 	 71 	 eps 	 0.5500	ep_reward 	 10.0000 	 reward 	 644.0000	GPI% 	 0.0000 	 w_err 	 7.3496
# test performance:
# task 	 0 	 steps 	 14000 	 episodes 	 76 	 eps 	 0.5500	ep_reward 	 10.0000 	 reward 	 685.0000	GPI% 	 0.0000 	 w_err 	 7.2054
# test performance:
# task 	 0 	 steps 	 15000 	 episodes 	 81 	 eps 	 0.5500	ep_reward 	 0.0000 	 reward 	 757.0000	GPI% 	 0.0000 	 w_err 	 6.9600
# test performance:
# task 	 0 	 steps 	 16000 	 episodes 	 86 	 eps 	 0.5500	ep_reward 	 20.0000 	 reward 	 827.0000	GPI% 	 0.0000 	 w_err 	 6.7243
# test performance:
# task 	 0 	 steps 	 17000 	 episodes 	 91 	 eps 	 0.5500	ep_reward 	 0.0000 	 reward 	 877.0000	GPI% 	 0.0000 	 w_err 	 6.5610
# test performance:
# task 	 0 	 steps 	 18000 	 episodes 	 96 	 eps 	 0.5500	ep_reward 	 10.0000 	 reward 	 957.0000	GPI% 	 0.0000 	 w_err 	 6.3083
# test performance:
# task 	 0 	 steps 	 19000 	 episodes 	 101 	 eps 	 0.5500	ep_reward 	 10.0000 	 reward 	 1027.0000	GPI% 	 0.0000 	 w_err 	 6.0956
# test performance:
# task 	 0 	 steps 	 20000 	 episodes 	 107 	 eps 	 0.5500	ep_reward 	 21.0000 	 reward 	 1108.0000	GPI% 	 0.0000 	 w_err 	 5.8608

# %%
rewards = agent.test_agent(tasks[0], return_history=1, visualize=1)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# --- Replay complete ---
