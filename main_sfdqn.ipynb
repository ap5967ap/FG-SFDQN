# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
from main_sfdqn import *

# %%
agent,train_tasks,test_task = main()
# Out:
# test performance:
# task 	 0 	 steps 	 1000 	 episodes 	 5 	 eps 	 0.5500	ep_reward 	 10.0000 	 reward 	 20.0000	GPI% 	 0.0000 	 w_err 	 10.0338
# test performance:
# task 	 0 	 steps 	 1000 	 episodes 	 5 	 eps 	 0.5500	ep_reward 	 10.0000 	 reward 	 20.0000	GPI% 	 0.0000 	 w_err 	 10.0338
# test performance:
# task 	 0 	 steps 	 2000 	 episodes 	 10 	 eps 	 0.5500	ep_reward 	 0.0000 	 reward 	 60.0000	GPI% 	 0.0000 	 w_err 	 9.9941
# test performance:
# task 	 0 	 steps 	 2000 	 episodes 	 10 	 eps 	 0.5500	ep_reward 	 0.0000 	 reward 	 60.0000	GPI% 	 0.0000 	 w_err 	 9.9941
# test performance:
# task 	 0 	 steps 	 3000 	 episodes 	 15 	 eps 	 0.5500	ep_reward 	 20.0000 	 reward 	 90.0000	GPI% 	 0.0000 	 w_err 	 9.9645
# test performance:
# task 	 0 	 steps 	 3000 	 episodes 	 15 	 eps 	 0.5500	ep_reward 	 20.0000 	 reward 	 90.0000	GPI% 	 0.0000 	 w_err 	 9.9645
# test performance:
# task 	 0 	 steps 	 4000 	 episodes 	 20 	 eps 	 0.5500	ep_reward 	 10.0000 	 reward 	 130.0000	GPI% 	 0.0000 	 w_err 	 9.9251
# test performance:
# task 	 0 	 steps 	 4000 	 episodes 	 20 	 eps 	 0.5500	ep_reward 	 10.0000 	 reward 	 130.0000	GPI% 	 0.0000 	 w_err 	 9.9251
# test performance:
# task 	 0 	 steps 	 5000 	 episodes 	 25 	 eps 	 0.5500	ep_reward 	 10.0000 	 reward 	 170.0000	GPI% 	 0.0000 	 w_err 	 9.8858
# test performance:
# task 	 0 	 steps 	 5000 	 episodes 	 25 	 eps 	 0.5500	ep_reward 	 10.0000 	 reward 	 170.0000	GPI% 	 0.0000 	 w_err 	 9.8858
# test performance:
# task 	 0 	 steps 	 6000 	 episodes 	 30 	 eps 	 0.5500	ep_reward 	 10.0000 	 reward 	 230.0000	GPI% 	 0.0000 	 w_err 	 9.8273
# test performance:
# task 	 0 	 steps 	 6000 	 episodes 	 30 	 eps 	 0.5500	ep_reward 	 10.0000 	 reward 	 230.0000	GPI% 	 0.0000 	 w_err 	 9.8273
# test performance:
# task 	 0 	 steps 	 7000 	 episodes 	 36 	 eps 	 0.5500	ep_reward 	 20.0000 	 reward 	 322.0000	GPI% 	 0.0000 	 w_err 	 9.7399
# test performance:
# task 	 0 	 steps 	 7000 	 episodes 	 36 	 eps 	 0.5500	ep_reward 	 20.0000 	 reward 	 322.0000	GPI% 	 0.0000 	 w_err 	 9.7399
# test performance:
# task 	 0 	 steps 	 8000 	 episodes 	 43 	 eps 	 0.5500	ep_reward 	 20.0000 	 reward 	 407.0000	GPI% 	 0.0000 	 w_err 	 9.6625
# test performance:
# task 	 0 	 steps 	 8000 	 episodes 	 43 	 eps 	 0.5500	ep_reward 	 20.0000 	 reward 	 407.0000	GPI% 	 0.0000 	 w_err 	 9.6625
# test performance:
# task 	 0 	 steps 	 9000 	 episodes 	 49 	 eps 	 0.5500	ep_reward 	 30.0000 	 reward 	 510.0000	GPI% 	 0.0000 	 w_err 	 9.5670
# test performance:
# task 	 0 	 steps 	 9000 	 episodes 	 49 	 eps 	 0.5500	ep_reward 	 30.0000 	 reward 	 510.0000	GPI% 	 0.0000 	 w_err 	 9.5670
# test performance:
# task 	 0 	 steps 	 10000 	 episodes 	 54 	 eps 	 0.5500	ep_reward 	 21.0000 	 reward 	 613.0000	GPI% 	 0.0000 	 w_err 	 9.4725
# test performance:
# task 	 0 	 steps 	 10000 	 episodes 	 54 	 eps 	 0.5500	ep_reward 	 21.0000 	 reward 	 613.0000	GPI% 	 0.0000 	 w_err 	 9.4725
# test performance:
# task 	 0 	 steps 	 11000 	 episodes 	 60 	 eps 	 0.5500	ep_reward 	 40.0000 	 reward 	 704.0000	GPI% 	 0.0000 	 w_err 	 9.3884
# test performance:
# task 	 0 	 steps 	 11000 	 episodes 	 60 	 eps 	 0.5500	ep_reward 	 40.0000 	 reward 	 704.0000	GPI% 	 0.0000 	 w_err 	 9.3884
# test performance:
# task 	 0 	 steps 	 12000 	 episodes 	 66 	 eps 	 0.5500	ep_reward 	 20.0000 	 reward 	 826.0000	GPI% 	 0.0000 	 w_err 	 9.2774
# test performance:
# task 	 0 	 steps 	 12000 	 episodes 	 66 	 eps 	 0.5500	ep_reward 	 20.0000 	 reward 	 826.0000	GPI% 	 0.0000 	 w_err 	 9.2774
# test performance:
# task 	 0 	 steps 	 13000 	 episodes 	 71 	 eps 	 0.5500	ep_reward 	 20.0000 	 reward 	 908.0000	GPI% 	 0.0000 	 w_err 	 9.2040
# test performance:
# task 	 0 	 steps 	 13000 	 episodes 	 71 	 eps 	 0.5500	ep_reward 	 20.0000 	 reward 	 908.0000	GPI% 	 0.0000 	 w_err 	 9.2040
# test performance:
# task 	 0 	 steps 	 14000 	 episodes 	 76 	 eps 	 0.5500	ep_reward 	 20.0000 	 reward 	 1029.0000	GPI% 	 0.0000 	 w_err 	 9.0953
# test performance:
# task 	 0 	 steps 	 14000 	 episodes 	 76 	 eps 	 0.5500	ep_reward 	 20.0000 	 reward 	 1029.0000	GPI% 	 0.0000 	 w_err 	 9.0953
# test performance:
# task 	 0 	 steps 	 15000 	 episodes 	 83 	 eps 	 0.5500	ep_reward 	 21.0000 	 reward 	 1153.0000	GPI% 	 0.0000 	 w_err 	 8.9876
# test performance:
# task 	 0 	 steps 	 15000 	 episodes 	 83 	 eps 	 0.5500	ep_reward 	 21.0000 	 reward 	 1153.0000	GPI% 	 0.0000 	 w_err 	 8.9876
# test performance:
# task 	 0 	 steps 	 16000 	 episodes 	 90 	 eps 	 0.5500	ep_reward 	 21.0000 	 reward 	 1300.0000	GPI% 	 0.0000 	 w_err 	 8.8633
# test performance:
# task 	 0 	 steps 	 16000 	 episodes 	 90 	 eps 	 0.5500	ep_reward 	 21.0000 	 reward 	 1300.0000	GPI% 	 0.0000 	 w_err 	 8.8633
# test performance:
# task 	 0 	 steps 	 17000 	 episodes 	 95 	 eps 	 0.5500	ep_reward 	 21.0000 	 reward 	 1394.0000	GPI% 	 0.0000 	 w_err 	 8.7844
# test performance:
# task 	 0 	 steps 	 17000 	 episodes 	 95 	 eps 	 0.5500	ep_reward 	 21.0000 	 reward 	 1394.0000	GPI% 	 0.0000 	 w_err 	 8.7844
# test performance:
# task 	 0 	 steps 	 18000 	 episodes 	 102 	 eps 	 0.5500	ep_reward 	 21.0000 	 reward 	 1519.0000	GPI% 	 0.0000 	 w_err 	 8.6803
# test performance:
# task 	 0 	 steps 	 18000 	 episodes 	 102 	 eps 	 0.5500	ep_reward 	 21.0000 	 reward 	 1519.0000	GPI% 	 0.0000 	 w_err 	 8.6803
# test performance:
# task 	 0 	 steps 	 19000 	 episodes 	 109 	 eps 	 0.5500	ep_reward 	 11.0000 	 reward 	 1692.0000	GPI% 	 0.0000 	 w_err 	 8.5354
# test performance:
# task 	 0 	 steps 	 19000 	 episodes 	 109 	 eps 	 0.5500	ep_reward 	 11.0000 	 reward 	 1692.0000	GPI% 	 0.0000 	 w_err 	 8.5354
# test performance:
# task 	 0 	 steps 	 20000 	 episodes 	 115 	 eps 	 0.5500	ep_reward 	 30.0000 	 reward 	 1844.0000	GPI% 	 0.0000 	 w_err 	 8.4096
# task 	 0 	 steps 	 20000 	 episodes 	 115 	 eps 	 0.5500	ep_reward 	 30.0000 	 reward 	 1844.0000	GPI% 	 0.0000 	 w_err 	 8.4096

# %%
rewards = agent.test_agent(test_tasks, return_history=1, visualize=1)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# --- Replay complete ---
