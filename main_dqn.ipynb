# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
from main_dqn import *

# %%
agent,tasks = main()
# Out:
# <tasks.gridworld.Shapes object at 0x7fa5db6082f0>
# test performance:
# /home/ritish/prog/ML/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ritish/prog/ML/.venv/lib/python3.13/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# task 	 0 	 steps 	 1000 	 episodes 	 5 	 eps 	 0.1500	ep_reward 	 0.0000 	 reward 	 10.0000
# test performance:
# task 	 0 	 steps 	 2000 	 episodes 	 11 	 eps 	 0.1500	ep_reward 	 0.0000 	 reward 	 21.0000
# test performance:
# task 	 0 	 steps 	 3000 	 episodes 	 16 	 eps 	 0.1500	ep_reward 	 0.0000 	 reward 	 31.0000
# test performance:
# task 	 0 	 steps 	 4000 	 episodes 	 21 	 eps 	 0.1500	ep_reward 	 11.0000 	 reward 	 63.0000
# test performance:
# task 	 0 	 steps 	 5000 	 episodes 	 26 	 eps 	 0.1500	ep_reward 	 0.0000 	 reward 	 83.0000
# test performance:
# task 	 0 	 steps 	 6000 	 episodes 	 31 	 eps 	 0.1500	ep_reward 	 30.0000 	 reward 	 133.0000
# test performance:
# task 	 0 	 steps 	 7000 	 episodes 	 36 	 eps 	 0.1500	ep_reward 	 0.0000 	 reward 	 163.0000
# test performance:
# task 	 0 	 steps 	 8000 	 episodes 	 41 	 eps 	 0.1500	ep_reward 	 0.0000 	 reward 	 183.0000
# test performance:
# task 	 0 	 steps 	 9000 	 episodes 	 46 	 eps 	 0.1500	ep_reward 	 10.0000 	 reward 	 243.0000
# test performance:
# task 	 0 	 steps 	 10000 	 episodes 	 52 	 eps 	 0.1500	ep_reward 	 21.0000 	 reward 	 346.0000
# test performance:
# task 	 0 	 steps 	 11000 	 episodes 	 59 	 eps 	 0.1500	ep_reward 	 21.0000 	 reward 	 481.0000
# test performance:
# task 	 0 	 steps 	 12000 	 episodes 	 65 	 eps 	 0.1500	ep_reward 	 30.0000 	 reward 	 633.0000
# test performance:
# task 	 0 	 steps 	 13000 	 episodes 	 70 	 eps 	 0.1500	ep_reward 	 30.0000 	 reward 	 703.0000
# test performance:
# task 	 0 	 steps 	 14000 	 episodes 	 75 	 eps 	 0.1500	ep_reward 	 10.0000 	 reward 	 813.0000
# test performance:
# task 	 0 	 steps 	 15000 	 episodes 	 80 	 eps 	 0.1500	ep_reward 	 20.0000 	 reward 	 943.0000
# test performance:
# task 	 0 	 steps 	 16000 	 episodes 	 85 	 eps 	 0.1500	ep_reward 	 20.0000 	 reward 	 1033.0000
# test performance:
# task 	 0 	 steps 	 17000 	 episodes 	 90 	 eps 	 0.1500	ep_reward 	 10.0000 	 reward 	 1113.0000
# test performance:
# task 	 0 	 steps 	 18000 	 episodes 	 95 	 eps 	 0.1500	ep_reward 	 20.0000 	 reward 	 1223.0000
# test performance:
# task 	 0 	 steps 	 19000 	 episodes 	 100 	 eps 	 0.1500	ep_reward 	 20.0000 	 reward 	 1353.0000
# test performance:
# task 	 0 	 steps 	 20000 	 episodes 	 105 	 eps 	 0.1500	ep_reward 	 30.0000 	 reward 	 1493.0000

# %%
rewards=agent.test_agent(tasks[0],return_history=1,visualize=1)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# --- Replay complete ---
