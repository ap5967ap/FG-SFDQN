# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
from main_dqn import *

# %%
agent,tasks = main()
# Out:
# <tasks.gridworld.Shapes object at 0x7f354630c980>
# test performance:
# /home/ritish/prog/ML/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ritish/prog/ML/.venv/lib/python3.13/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# task 	 0 	 steps 	 1000 	 episodes 	 5 	 eps 	 0.5500	ep_reward 	 0.0000 	 reward 	 10.0000
# test performance:
# task 	 0 	 steps 	 2000 	 episodes 	 10 	 eps 	 0.5500	ep_reward 	 10.0000 	 reward 	 30.0000
# test performance:
# task 	 0 	 steps 	 3000 	 episodes 	 15 	 eps 	 0.5500	ep_reward 	 30.0000 	 reward 	 80.0000
# test performance:
# task 	 0 	 steps 	 4000 	 episodes 	 21 	 eps 	 0.5500	ep_reward 	 10.0000 	 reward 	 141.0000
# test performance:
# task 	 0 	 steps 	 5000 	 episodes 	 26 	 eps 	 0.5500	ep_reward 	 0.0000 	 reward 	 151.0000
# test performance:
# task 	 0 	 steps 	 6000 	 episodes 	 31 	 eps 	 0.5500	ep_reward 	 0.0000 	 reward 	 151.0000
# test performance:
# task 	 0 	 steps 	 7000 	 episodes 	 36 	 eps 	 0.5500	ep_reward 	 0.0000 	 reward 	 151.0000
# test performance:
# task 	 0 	 steps 	 8000 	 episodes 	 41 	 eps 	 0.5500	ep_reward 	 20.0000 	 reward 	 212.0000
# test performance:
# task 	 0 	 steps 	 9000 	 episodes 	 46 	 eps 	 0.5500	ep_reward 	 11.0000 	 reward 	 283.0000
# test performance:
# task 	 0 	 steps 	 10000 	 episodes 	 52 	 eps 	 0.5500	ep_reward 	 11.0000 	 reward 	 355.0000
# test performance:
# task 	 0 	 steps 	 11000 	 episodes 	 58 	 eps 	 0.5500	ep_reward 	 10.0000 	 reward 	 426.0000
# test performance:
# task 	 0 	 steps 	 12000 	 episodes 	 63 	 eps 	 0.5500	ep_reward 	 20.0000 	 reward 	 538.0000
# test performance:
# task 	 0 	 steps 	 13000 	 episodes 	 68 	 eps 	 0.5500	ep_reward 	 30.0000 	 reward 	 649.0000
# test performance:
# task 	 0 	 steps 	 14000 	 episodes 	 73 	 eps 	 0.5500	ep_reward 	 20.0000 	 reward 	 759.0000
# test performance:
# task 	 0 	 steps 	 15000 	 episodes 	 78 	 eps 	 0.5500	ep_reward 	 20.0000 	 reward 	 869.0000
# test performance:
# task 	 0 	 steps 	 16000 	 episodes 	 84 	 eps 	 0.5500	ep_reward 	 21.0000 	 reward 	 1000.0000
# test performance:
# task 	 0 	 steps 	 17000 	 episodes 	 89 	 eps 	 0.5500	ep_reward 	 20.0000 	 reward 	 1110.0000
# test performance:
# task 	 0 	 steps 	 18000 	 episodes 	 94 	 eps 	 0.5500	ep_reward 	 30.0000 	 reward 	 1270.0000
# test performance:
# task 	 0 	 steps 	 19000 	 episodes 	 99 	 eps 	 0.5500	ep_reward 	 21.0000 	 reward 	 1391.0000
# test performance:
# task 	 0 	 steps 	 20000 	 episodes 	 105 	 eps 	 0.5500	ep_reward 	 30.0000 	 reward 	 1553.0000

# %%
rewards=agent.test_agent(tasks[0],return_history=1,visualize=1)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# --- Replay complete ---
