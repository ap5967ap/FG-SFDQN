# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
from main_dqn import *

# %%
agent,tasks = main()
# Out:
# <tasks.gridworld.Shapes object at 0x7f9118755d30>
# test performance:
# /home/ritish/prog/ML/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ritish/prog/ML/.venv/lib/python3.13/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# task 	 0 	 steps 	 1000 	 episodes 	 5 	 eps 	 0.5500	ep_reward 	 20.0000 	 reward 	 50.0000
# test performance:
# task 	 0 	 steps 	 2000 	 episodes 	 10 	 eps 	 0.5500	ep_reward 	 10.0000 	 reward 	 60.0000
# test performance:
# task 	 0 	 steps 	 3000 	 episodes 	 15 	 eps 	 0.5500	ep_reward 	 10.0000 	 reward 	 70.0000
# test performance:
# task 	 0 	 steps 	 4000 	 episodes 	 21 	 eps 	 0.5500	ep_reward 	 0.0000 	 reward 	 111.0000
# test performance:
# task 	 0 	 steps 	 5000 	 episodes 	 27 	 eps 	 0.5500	ep_reward 	 21.0000 	 reward 	 193.0000
# test performance:
# task 	 0 	 steps 	 6000 	 episodes 	 32 	 eps 	 0.5500	ep_reward 	 21.0000 	 reward 	 285.0000
# test performance:
# task 	 0 	 steps 	 7000 	 episodes 	 38 	 eps 	 0.5500	ep_reward 	 1.0000 	 reward 	 378.0000
# test performance:
# task 	 0 	 steps 	 8000 	 episodes 	 44 	 eps 	 0.5500	ep_reward 	 11.0000 	 reward 	 471.0000
# test performance:
# task 	 0 	 steps 	 9000 	 episodes 	 49 	 eps 	 0.5500	ep_reward 	 10.0000 	 reward 	 562.0000
# test performance:
# task 	 0 	 steps 	 10000 	 episodes 	 54 	 eps 	 0.5500	ep_reward 	 31.0000 	 reward 	 663.0000
# test performance:
# task 	 0 	 steps 	 11000 	 episodes 	 60 	 eps 	 0.5500	ep_reward 	 11.0000 	 reward 	 805.0000
# test performance:
# task 	 0 	 steps 	 12000 	 episodes 	 65 	 eps 	 0.5500	ep_reward 	 20.0000 	 reward 	 935.0000
# test performance:
# task 	 0 	 steps 	 13000 	 episodes 	 70 	 eps 	 0.5500	ep_reward 	 20.0000 	 reward 	 1056.0000
# test performance:
# task 	 0 	 steps 	 14000 	 episodes 	 78 	 eps 	 0.5500	ep_reward 	 30.0000 	 reward 	 1181.0000
# test performance:
# task 	 0 	 steps 	 15000 	 episodes 	 83 	 eps 	 0.5500	ep_reward 	 20.0000 	 reward 	 1291.0000
# test performance:
# task 	 0 	 steps 	 16000 	 episodes 	 89 	 eps 	 0.5500	ep_reward 	 31.0000 	 reward 	 1454.0000
# test performance:
# task 	 0 	 steps 	 17000 	 episodes 	 94 	 eps 	 0.5500	ep_reward 	 20.0000 	 reward 	 1566.0000
# test performance:
# task 	 0 	 steps 	 18000 	 episodes 	 99 	 eps 	 0.5500	ep_reward 	 40.0000 	 reward 	 1726.0000
# test performance:
# task 	 0 	 steps 	 19000 	 episodes 	 104 	 eps 	 0.5500	ep_reward 	 30.0000 	 reward 	 1906.0000
# test performance:
# task 	 0 	 steps 	 20000 	 episodes 	 109 	 eps 	 0.5500	ep_reward 	 40.0000 	 reward 	 2067.0000

# %%
rewards=agent.test_agent(tasks[0],return_history=1,visualize=1)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 rewards=agent.test_agent(tasks[0],return_history=1,visualize=1)
#
# File ~/prog/ML/adv_rl/agents/dqn.py:206, in DQN.test_agent(self, task, return_history, visualize, pause, max_steps)
#     197 episode = {
#     198     "total_reward": total_reward,
#     199     "steps": len(actions),
#    (...)
#     202     "rewards": rewards
#     203 }
#     205 if visualize:
# --> 206     Agent.render_episode_history_rich(episode, task, agent=self, pause=pause)
#     208 if return_history:
#     209     return episode
#
# File ~/prog/ML/adv_rl/agents/agent.py:372, in Agent.render_episode_history_rich(episode, task, agent, pause, style_map)
#     370             break
#     371         import time
# --> 372         time.sleep(pause)
#     373 console.print("--- Replay complete ---", style="bold magenta")
#
# KeyboardInterrupt:
