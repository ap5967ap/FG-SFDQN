# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
from main_dqn import *

# %%
agent,tasks = main()
# Out:
# <tasks.gridworld.Shapes object at 0x7f7343516210>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 agent,tasks = main()
#
# File ~/prog/ML/adv_rl/main_dqn.py:81, in main()
#      79 train_tasks = [task]
#      80 n_samples=conf['n_samples']
# ---> 81 agent.train(train_tasks=train_tasks, n_samples=n_samples, test_tasks=[])
#      82 return (agent,train_tasks)
#
# File ~/prog/ML/adv_rl/agents/dqn.py:115, in DQN.train(self, train_tasks, n_samples, viewers, n_view_ev, test_tasks, n_test_ev)
#     111 self.set_active_training_task(index)
#     112 for t in range(n_samples):
#     113
#     114     # train
# --> 115     self.next_sample(viewer, n_view_ev)
#     117     # test
#     118     if t % n_test_ev == 0:
#
# File ~/prog/ML/adv_rl/agents/agent.py:196, in Agent.next_sample(self, viewer, n_view_ev)
#     193         self.episode_reward_hist.append(self.episode_reward)
#     195 # compute the Q-values in the current state
# --> 196 q = self.get_Q_values(self.s, self.s_enc)
#     198 # choose an action using the epsilon-greedy policy
#     199 a = self._epsilon_greedy(q)
#
# File ~/prog/ML/adv_rl/agents/dqn.py:47, in DQN.get_Q_values(self, s, s_enc)
#      45     s_enc_tensor = torch.from_numpy(s_enc).float()
#      46     q_values = self.Q(s_enc_tensor)
# ---> 47 return q_values.numpy()
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %%
rewards=agent.test_agent(tasks[0],return_history=1,visualize=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 rewards=agent.test_agent(tasks[0],return_history=1,visualize=1)
#
# NameError: name 'agent' is not defined
