# %%
from main_dqn import *
# Out:
# 2025-10-04 23:48:02.785218: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
agent,tasks = main()
# Out:
# ...
# test performance:
# /home/ap/miniconda3/envs/rl/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ap/miniconda3/envs/rl/lib/python3.10/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# task 	 0 	 steps 	 1000 	 episodes 	 5 	 eps 	 0.1500	ep_reward 	 0.0000 	 reward 	 0.0000
# test performance:
# task 	 0 	 steps 	 2000 	 episodes 	 11 	 eps 	 0.1500	ep_reward 	 10.0000 	 reward 	 21.0000
# test performance:
# task 	 0 	 steps 	 3000 	 episodes 	 16 	 eps 	 0.1500	ep_reward 	 10.0000 	 reward 	 61.0000
# test performance:
# task 	 0 	 steps 	 4000 	 episodes 	 21 	 eps 	 0.1500	ep_reward 	 0.0000 	 reward 	 71.0000
# test performance:
# task 	 0 	 steps 	 5000 	 episodes 	 26 	 eps 	 0.1500	ep_reward 	 0.0000 	 reward 	 81.0000
# test performance:
# ...

# %%
rewards=agent.test_agent(tasks[0],return_history=1,visualize=1)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 rewards=agent.test_agent(tasks[0],return_history=1,visualize=1)
#
# File ~/Downloads/sfr/agents/dqn.py:205, in DQN.test_agent(self, task, return_history, visualize, pause, max_steps)
#     196 episode = {
#     197     "total_reward": total_reward,
#     198     "steps": len(actions),
#    (...)
#     201     "rewards": rewards
#     202 }
#     204 if visualize:
# --> 205     self.render_episode_history_rich(episode, task, agent=self, pause=pause)
#     207 if return_history:
#     208     return episode
#
# File ~/Downloads/sfr/agents/dqn.py:334, in DQN.render_episode_history_rich(episode, task, agent, pause, style_map)
# ...
